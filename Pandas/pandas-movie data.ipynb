# %%
import pandas as pd
data=pd.read_csv('moviesdata.csv')
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
data.shape
# Out:
# (1465, 12)

# %%
data.size
# Out:
# 17580

# %%
data.describe()
# Out:
#         Unnamed: 0            id        budget   popularity       revenue  \
# count  1465.000000   1465.000000  1.465000e+03  1465.000000  1.465000e+03
# mean   1627.391809  45225.191126  4.802295e+07    30.855973  1.432539e+08
# std    1187.182894   1189.096396  4.935541e+07    34.845214  2.064918e+08
# min       0.000000  43597.000000  0.000000e+00     0.000000  0.000000e+00
# 25%     639.000000  44236.000000  1.400000e+07    11.000000  1.738013e+07
# 50%    1425.000000  45022.000000  3.300000e+07    23.000000  7.578164e+07
# 75%    2393.000000  45990.000000  6.600000e+07    41.000000  1.792469e+08
# max    4768.000000  48395.000000  3.800000e+08   724.000000  2.787965e+09
#
#        vote_average    vote_count  director_id         year
# count   1465.000000   1465.000000  1465.000000  1465.000000
# mean       6.368191   1146.396587  5040.192491  2002.615017
# std        0.818033   1578.077438   258.059631     8.680141
# min        3.000000      1.000000  4762.000000  1976.000000
# ...

# %%
data.describe().T
# Out:
#                count          mean           std      min         25%  \
# Unnamed: 0    1465.0  1.627392e+03  1.187183e+03      0.0       639.0
# id            1465.0  4.522519e+04  1.189096e+03  43597.0     44236.0
# budget        1465.0  4.802295e+07  4.935541e+07      0.0  14000000.0
# popularity    1465.0  3.085597e+01  3.484521e+01      0.0        11.0
# revenue       1465.0  1.432539e+08  2.064918e+08      0.0  17380126.0
# vote_average  1465.0  6.368191e+00  8.180335e-01      3.0         5.9
# vote_count    1465.0  1.146397e+03  1.578077e+03      1.0       216.0
# director_id   1465.0  5.040192e+03  2.580596e+02   4762.0      4845.0
# year          1465.0  2.002615e+03  8.680141e+00   1976.0      1998.0
#
#                      50%          75%           max
# Unnamed: 0        1425.0       2393.0  4.768000e+03
# id               45022.0      45990.0  4.839500e+04
# budget        33000000.0   66000000.0  3.800000e+08
# popularity          23.0         41.0  7.240000e+02
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'budget', 'popularity', 'revenue', 'title',
#        'vote_average', 'vote_count', 'director_id', 'year', 'month', 'day'],
#       dtype='object')

# %%
data.tail(10)
# Out:
#       Unnamed: 0     id  budget  popularity  revenue              title  \
# 1455        4684  48310  160000           3  6706368         Roger & Me
# 1456        4694  48321   10000          20  7000000         Eraserhead
# 1457        4696  48323       0           5        0         The Mighty
# 1458        4708  48335   60000          27  3221152                 Pi
# 1459        4732  48359       0           2        0  George Washington
# 1460        4736  48363       0           3   321952     The Last Waltz
# 1461        4743  48370   27000          19  3151130             Clerks
# 1462        4748  48375       0           7        0            Rampage
# 1463        4749  48376       0           3        0            Slacker
# 1464        4768  48395  220000          14  2040920        El Mariachi
#
#       vote_average  vote_count  director_id  year month       day
# 1455           7.4          90         5697  1989   Sep    Friday
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0     id  budget  popularity  revenue           title  \
# 1460        4736  48363       0           3   321952  The Last Waltz
# 1461        4743  48370   27000          19  3151130          Clerks
# 1462        4748  48375       0           7        0         Rampage
# 1463        4749  48376       0           3        0         Slacker
# 1464        4768  48395  220000          14  2040920     El Mariachi
#
#       vote_average  vote_count  director_id  year month      day
# 1460           7.9          64         4809  1978   May   Monday
# 1461           7.4         755         5369  1994   Sep  Tuesday
# 1462           6.0         131         5148  2009   Aug   Friday
# 1463           6.4          77         5535  1990   Jul   Friday
# 1464           6.6         238         5097  1992   Sep   Friday

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
data.head(7)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
# 6          10  43607  270000000          57   391081192
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
# 5        Batman v Superman: Dawn of Justice           5.7        7004
# ...

# %%
#range of popularity
#films  shown on saturday
#extract in specific year

# %%
a=data[(data['popularity']>100)]
a
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# 5              9  43606  250000000         155   873260194
# 7             11  43608  200000000         107   586090727
# 8             12  43609  200000000         145  1065659812
# 12            17  43614  380000000         135  1045713802
# 14            19  43616  250000000         120   956019788
# 26            36  43633  210000000         116  1091405097
# 30            44  43641  190000000         102  1506249360
# 32            46  43643  250000000         118   747862775
# 44            64  43661  178000000         139   543934787
# 45            65  43662  185000000         187  1004558444
# ...

# %%
b=data['day']=='saturday'
b
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: day, Length: 1465, dtype: bool

# %%
a=data[data['year']==2006]
a
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
b=data[data['day']=='Saturday']
b
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 1              1  43598  300000000         139   961000000
# 12            17  43614  380000000         135  1045713802
# 40            59  43656  200000000          45   769653595
# 51            73  43670  175000000          27   173000000
# 70           114  43711  150000000         101   895921036
# 187          302  43899   80000000          37   140073390
# 191          316  43913  100000000          46   193772504
# 198          327  43924   65000000          29    93525586
# 212          353  43950   92000000          43   188072649
# 246          405  44002   85000000           8   158468292
# 281          475  44072          0          20    43312294
# 396          687  44284   65000000          65   422610419
# 547          997  44594   50000000          37    55969000
# 655         1231  44828   40000000          31    55247881
# 725         1407  45004   40000000          17    68766121
# ...
